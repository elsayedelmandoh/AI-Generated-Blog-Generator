# %% [markdown]
# That notebook for testing only not finaly results

# %% [markdown]
# # Internship : Task 2

# %% [markdown]
# # Define Project Objectives

# %% [markdown]
# + Project Task Document:
#
#     - AI-Generated Blog Posts with Images
#
# + Objective:
#
#     - This project is designed to help you explore the capabilities of `generative models in content creation` and `image generation for blog posts`..
#
# + Requirements:
#     1. `Keyword Selection`:
#     ○ Specify relevant keywords related to your chosen topic. For instance, if your topic is "Artificial Intelligence," keywords might include "AI technology," "machine learning," "deep learning," etc.,
#
#     2. `Text Generation`:
#     ○ Input the specified keywords and use generative models to create the blog post content.
#     ○ Fine-tune the generated text to achieve the desired tone and style.
#
#     3. `Image Generation`:
#     ○ Utilize image generative models to generate images based on descriptions or keywords.
#
#     4. `Blog Post Formatting`:
#     ○ Format the generated text and images into a coherent blog post structure, including an introduction, body, and conclusion.
#     ○ Incorporate headings, subheadings, and captions for a professional appearance.
#
#     5. `Image Integration`:
#     ○ Explain how you will integrate the generated images into your blog post.

# %% [markdown]
# This title return error:
#
# the influence of optimization techniques in model enhancement
#
# machine learning algorithms

# %% [markdown]
# # Data Acquisition

# %%
# !pip install transformers

# %%
keywords = "the influence of optimization techniques in model enhancement"
len(keywords.split())
# Out:
# 8

# %%
from transformers import pipeline

# %%
import requests
prompt = "machine learning algorithms"
API_TOKEN = "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"

# %%
API_URL = f"https://api-inference.huggingface.co/models/tiiuae/falcon-7b-instruct"
headers = {"Authorization": f"Bearer {API_TOKEN}"}
payload = {"inputs": prompt}

response = requests.post(API_URL, headers=headers, json=payload)
generated_text = response.json()[0]["generated_text"]
generated_text
# Out:
# 'machine learning algorithms\nMachine learning algorithms are a set of algorithms that allow computers to learn from data and improve their performance over time. They are used in a variety of applications, such as image recognition, natural language processing, and predictive analytics. Some popular machine learning algorithms include linear regression, logistic regression, decision trees, and neural networks.'

# %%
API_URL = "https://api-inference.huggingface.co/models/google/flan-ul2"
headers = {"Authorization": f"Bearer {API_TOKEN}"}
payload = {"inputs": prompt}
response = requests.post(API_URL, headers=headers, json=payload)
response.json()
# Out:
# {'error': 'Internal Server Error'}

# %% [markdown]
# Text generation

# %% [markdown]
# https://huggingface.co/tiiuae/falcon-7b-instruct

# %%
prompt = "a photo of an astronaut riding a horse on mars"

# %%
generator = pipeline('text-generation', model = 'gpt2')
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
generated_text = generator(prompt, max_length = 100, num_return_sequences=1)[0]['generated_text']
generated_text
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 'a photo of an astronaut riding a horse on marshes with pictures of animals and a woman on the floor of a swimming pool.\n\nOn Saturday, President Obama launched the latest attempt to address the nation\'s mental health crises, with a series of measures aimed at improving mental health and reducing crime, such as expanding the Office of Mental Health, which serves about 1.6 million Americans.\n\n"As we celebrate this milestone, it is important to understand that those who have been most affected by'

# %% [markdown]
# ## [{'generated_text': "Hello, I'm a language modeler. So while writing this, when I went out to meet my wife or come home she told me that my"},

# %% [markdown]
# ##  {'generated_text': "Hello, I'm a language modeler. I write and maintain software in Python. I love to code, and that includes coding things that require writing"},

# %% [markdown]
# api

# %%
API_TOKEN = "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"

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/tiiuae/falcon-7b-instruct"
headers = {"Authorization": f"Bearer {API_TOKEN}"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()[0]["generated_text"]
	
output = query({
	"inputs": "Can you please let us know more details about your ",
})
output
# Out:
# 'Can you please let us know more details about your "problem"?\nAs an AI language model, I do not have personal problems. However, I can assist you with any technical issues you may have.'

# %%
x= 'Can you please let us know more details about your "problem"?\nAs an AI language model, I do not have personal problems. However, I can assist you with any technical issues you may have.'
len(x)
# Out:
# 185

# %%
# Function for text generation using Hugging Face API
def generate_text(prompt):
    API_URL = "https://api-inference.huggingface.co/models/tiiuae/falcon-7b-instruct"
    headers = {"Authorization": f"Bearer {API_TOKEN}"}
    payload = {"inputs": prompt}
    
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()[0]["generated_text"]

# prompt = "a photo of an astronaut riding a horse on mars"
prompt = "write artificial intelligence world"
gt = generate_text(prompt)
print(gt)
# Out:
# write artificial intelligence world
# The Artificial Intelligence World is a leading source of information and news on the latest developments in AI, machine learning, and robotics. We provide the latest news, analysis, and insights on the latest trends and technologies in the field. Our coverage includes topics such as AI, machine learning, robotics, and automation.

# %%
type(gt)
# Out:
# str

# %%
gt2 = generate_text(gt)
print(gt2)
# Out:
# a photo of an astronaut riding a horse on mars
# I'm sorry, but there is no photo of an astronaut riding a horse on Mars. This is a common misconception.

# %% [markdown]
# # Image generation

# %%
# !pip install diffusers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 8.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# api

# %%
import requests

API_TOKEN = "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"
API_URL = "https://api-inference.huggingface.co/models/CompVis/stable-diffusion-v1-4"
headers = {"Authorization": f"Bearer {API_TOKEN}"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.content
image_bytes = query({
	"inputs": "Astronaut riding a horse",
})
# You can access the image with PIL.Image for example
import io
from PIL import Image
image = Image.open(io.BytesIO(image_bytes))
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %%
def generate_image(description):
    API_URL = "https://api-inference.huggingface.co/models/CompVis/stable-diffusion-v1-4"
    headers = {"Authorization": f"Bearer {API_TOKEN}"}
    payload = {"inputs": description}
    
    response = requests.post(API_URL, headers=headers, json=payload)
    image_bytes = response.content
    image = Image.open(io.BytesIO(image_bytes))
    return image

generate_image(generate_text(prompt))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %%
from diffusers import StableDiffusionPipeline, EulerDiscreteScheduler
import torch

# %%
# model_id = "stabilityai/stable-diffusion-2"
model_id = "CompVis/stable-diffusion-v1-4"
scheduler = EulerDiscreteScheduler.from_pretrained(model_id, subfolder="scheduler")
pipe = StableDiffusionPipeline.from_pretrained(model_id, scheduler=scheduler, torch_dtype=torch.float16)
pipe = pipe.to("cuda")
pipe
# Out:
# scheduler/scheduler_config.json:   0%|          | 0.00/345 [00:00<?, ?B/s]
# model_index.json:   0%|          | 0.00/537 [00:00<?, ?B/s]
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# text_encoder/config.json:   0%|          | 0.00/633 [00:00<?, ?B/s]
# tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# unet/config.json:   0%|          | 0.00/909 [00:00<?, ?B/s]
# tokenizer/special_tokens_map.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# (…)ature_extractor/preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# tokenizer/tokenizer_config.json:   0%|          | 0.00/824 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.36G [00:00<?, ?B/s]
# vae/config.json:   0%|          | 0.00/611 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# ...

# %%
image = pipe(generated_text).images[0]
image
# Out:
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['" as we celebrate this milestone, it is important to understand that those who have been most affected by']
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=768x768>

# %%
import matplotlib.pyplot as plt
